# %% [markdown]
# # Topics To Cover
# 1)Read a CSV Data file with index

# %% [markdown]
# # Import all  necessary libraries

# %%
import pandas as pd

# %% [markdown]
# # Read a csv file: assign variable "Data_csv"

# %%
#Read a csv file: assign variable "Data_csv"

Data_csv = pd.read_csv("~/train.csv")
#Data_csv = pd.read_csv("url")
Data_csv.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %%
#Suppose if you dont have(want) columns name
Data_csv1 = pd.read_csv("~/train.csv",header=None)
Data_csv1.head()
# Out:
#          0       1        2           3             4              5   \
# 0   Loan_ID  Gender  Married  Dependents     Education  Self_Employed
# 1  LP001002    Male       No           0      Graduate             No
# 2  LP001003    Male      Yes           1      Graduate             No
# 3  LP001005    Male      Yes           0      Graduate            Yes
# 4  LP001006    Male      Yes           0  Not Graduate             No
#
#                 6                  7           8                 9   \
# 0  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# 1             5849                  0         NaN               360
# 2             4583               1508         128               360
# 3             3000                  0          66               360
# 4             2583               2358         120               360
#
#                10             11           12
# 0  Credit_History  Property_Area  Loan_Status
# 1               1          Urban            Y
# 2               1          Rural            N
# 3               1          Urban            Y
# 4               1          Urban            Y

# %%
#Suppose if you want to assign new column name as per your wish:
#Assign all col name in a variable
col_name = ["Loan_ID","Gender","Married","Dependents","Education","Self_Employed","ApplicantIncome","CoapplicantIncome","LoanAmount","Loan_Amount_Term","Credit_History","Property_Area","Loan_Status"]
Data_csv2 = pd.read_csv("~/train.csv",names =col_name)
Data_csv2.head()
# Out:
#     Loan_ID  Gender  Married  Dependents     Education  Self_Employed  \
# 0   Loan_ID  Gender  Married  Dependents     Education  Self_Employed
# 1  LP001002    Male       No           0      Graduate             No
# 2  LP001003    Male      Yes           1      Graduate             No
# 3  LP001005    Male      Yes           0      Graduate            Yes
# 4  LP001006    Male      Yes           0  Not Graduate             No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0  ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# 1             5849                  0         NaN               360
# 2             4583               1508         128               360
# 3             3000                  0          66               360
# 4             2583               2358         120               360
#
#    Credit_History  Property_Area  Loan_Status
# 0  Credit_History  Property_Area  Loan_Status
# 1               1          Urban            Y
# 2               1          Rural            N
# 3               1          Urban            Y
# 4               1          Urban            Y

# %%
#now you can delete the first row of the table
Data_csv2 = Data_csv2.drop(Data_csv2.index[0])
Data_csv2.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1  LP001002   Male      No          0      Graduate            No
# 2  LP001003   Male     Yes          1      Graduate            No
# 3  LP001005   Male     Yes          0      Graduate           Yes
# 4  LP001006   Male     Yes          0  Not Graduate            No
# 5  LP001008   Male      No          0      Graduate            No
#
#   ApplicantIncome CoapplicantIncome LoanAmount Loan_Amount_Term  \
# 1            5849                 0        NaN              360
# 2            4583              1508        128              360
# 3            3000                 0         66              360
# 4            2583              2358        120              360
# 5            6000                 0        141              360
#
#   Credit_History Property_Area Loan_Status
# 1              1         Urban           Y
# 2              1         Rural           N
# 3              1         Urban           Y
# 4              1         Urban           Y
# 5              1         Urban           Y

# %%
#Use first column as Index
Data_csv3 = pd.read_csv("~/train.csv",index_col="Loan_ID")
Data_csv3.head()
# Out:
#          Gender Married Dependents     Education Self_Employed  \
# Loan_ID
# LP001002   Male      No          0      Graduate            No
# LP001003   Male     Yes          1      Graduate            No
# LP001005   Male     Yes          0      Graduate           Yes
# LP001006   Male     Yes          0  Not Graduate            No
# LP001008   Male      No          0      Graduate            No
#
#           ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# Loan_ID
# LP001002             5849                0.0         NaN             360.0
# LP001003             4583             1508.0       128.0             360.0
# LP001005             3000                0.0        66.0             360.0
# LP001006             2583             2358.0       120.0             360.0
# LP001008             6000                0.0       141.0             360.0
#
#           Credit_History Property_Area Loan_Status
# Loan_ID
# LP001002             1.0         Urban           Y
# LP001003             1.0         Rural           N
# LP001005             1.0         Urban           Y
# LP001006             1.0         Urban           Y
# LP001008             1.0         Urban           Y

# %% [markdown]
# # Read a Text File

# %%
columns =['State','Account_Len','Area','Ph_No.','Int_Plan','Vmail_Plan','messgs',
            'tot_day_mins','tot_day_calls','tot_day_chrgs','tot_evening_mins',
            'tot_evening_calls','tot_evening_chrgs','tot_ngt_mins','tot_ngt_calls',
            'tot_ngt_chrgs','tot_int_mins','tot_int_calls','tot_int_chrgs',
'cust_calls_made','churn_status']

Data_txt = pd.read_csv("~/telecom_churn_data.txt",names=columns)
Data_txt.head()
# Out:
#   State  Account_Len  Area     Ph_No. Int_Plan Vmail_Plan  messgs  \
# 0    KS          128   415   382-4657       no        yes      25
# 1    OH          107   415   371-7191       no        yes      26
# 2    NJ          137   415   358-1921       no         no       0
# 3    OH           84   408   375-9999      yes         no       0
# 4    OK           75   415   330-6626      yes         no       0
#
#    tot_day_mins  tot_day_calls  tot_day_chrgs      ...       \
# 0         265.1            110          45.07      ...
# 1         161.6            123          27.47      ...
# 2         243.4            114          41.38      ...
# 3         299.4             71          50.90      ...
# 4         166.7            113          28.34      ...
#
#    tot_evening_calls  tot_evening_chrgs  tot_ngt_mins  tot_ngt_calls  \
# 0                 99              16.78         244.7             91
# 1                103              16.62         254.4            103
# 2                110              10.30         162.6            104
# 3                 88               5.26         196.9             89
# 4                122              12.61         186.9            121
#
#    tot_ngt_chrgs  tot_int_mins  tot_int_calls  tot_int_chrgs  cust_calls_made  \
# 0          11.01          10.0              3           2.70                1
# 1          11.45          13.7              3           3.70                1
# 2           7.32          12.2              5           3.29                0
# 3           8.86           6.6              7           1.78                2
# 4           8.41          10.1              3           2.73                3
#
#    churn_status
# 0        False.
# 1        False.
# 2        False.
# 3        False.
# 4        False.
#
# [5 rows x 21 columns]
